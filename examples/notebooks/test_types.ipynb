# %%
from vedo import np, Points
pts = Points(np.random.randn(1000,3)).color("green5")
pts
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Points: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/pointcloud.html#Points" target="_blank">vedo.pointcloud.Points</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>-3.182 ... 3.063<br/>-3.169 ... 3.330<br/>-3.481 ... 3.360</td></tr>
# <tr><td><b> center of mass </b></td><td>(0.0136, -0.0422, 0.0281)</td></tr>
# <tr><td><b> average size </b></td><td>1.613</td></tr>
# <tr><td><b> nr. points </b></td><td>1000</td></tr>
#
#
# </table>
# </table>

# %%
from vedo import dataurl, Mesh
mesh = Mesh(dataurl + "bunny.obj")
mesh.name = "Mr. Rabbit"
mesh.compute_quality().cmap("Reds")
mesh
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Mr. Rabbit: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/mesh.html#Mesh" target="_blank">vedo.mesh.Mesh</a></b><br/><code><i>(...mbl.es/examples/data/bunny.obj)</i></code>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>-0.09438 ... 0.06078<br/>0.03331 ... 0.1870<br/>-0.06168 ... 0.05871</td></tr>
# <tr><td><b> center of mass </b></td><td>(-0.0280, 0.0942, 9.05e-3)</td></tr>
# <tr><td><b> average size </b></td><td>0.063</td></tr>
# <tr><td><b> nr. points&nbsp/&nbspfaces </b></td><td>2503&nbsp/&nbsp4968</td></tr>
#
# <tr><td><b> cell data array </b></td><td>Quality</td></tr>
# </table>
# </table>

# %%
from vedo import dataurl, Volume
vol = Volume(dataurl+"embryo.tif")
vol.name = "Wild-type Embryo"
vol
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Wild-type Embryo: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/volume.html" target="_blank">vedo.volume.Volume</a></b><br/><code><i>(...me/musy/.cache/vedo/embryo.tif)</i></code>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 1.290e+4<br/>0 ... 8219<br/>0 ... 1.103e+4</td></tr>
# <tr><td><b> dimensions </b></td><td>(125, 80, 107)</td></tr>
# <tr><td><b> voxel spacing </b></td><td>(104, 104, 104)</td></tr>
# <tr><td><b> in memory size </b></td><td>1MB</td></tr>
# <tr><td><b> point data array </b></td><td>Tiff Scalars</td></tr>
#
# <tr><td><b> scalar range </b></td><td>(0, 150.0)</td></tr>
# </table>
# </table>

# %%
from vedo import Image
pic = Image("https://i.natgeofe.com/n/548467d8-c5f1-4551-9f58-6817a8d2c45e/NationalGeographic_2572187_2x3.jpg")
pic.name = "Domestic Cat"
pic
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Domestic Cat: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/image.html" target="_blank">vedo.image.Image</a></b><br/><code><i>(...onalGeographic_2572187_2x3.jpg)</i></code>
# <table>
# <tr><td><b> shape </b></td><td>(2048, 3072)</td></tr>
# <tr><td><b> in memory size </b></td><td>18432 KB</td></tr>
# <tr><td><b> point data array </b></td><td>JPEGImage</td></tr>
#
# <tr><td><b> intensity range </b></td><td>(0.0, 255.0)</td></tr>
# <tr><td><b> level&nbsp/&nbspwindow </b></td><td>127.5&nbsp/&nbsp255.0</td></tr>
# </table>
# </table>

# %%
from vedo import dataurl, TetMesh
tet = TetMesh(dataurl+"limb_ugrid.vtk")
tet.name = "MouseLimb"
tet
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> MouseLimb: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/grids.html#TetMesh" target="_blank">vedo.grids.TetMesh</a></b><br/><code><i>(...usy/.cache/vedo/limb_ugrid.vtk)</i></code>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 1416<br/>-711.3 ... 700.2<br/>-851.6 ... 463.9</td></tr>
# <tr><td><b> center of mass </b></td><td>(582, 18.1, -252)</td></tr>
# <tr><td><b> nr. points&nbsp/&nbsptets </b></td><td>10926&nbsp/&nbsp58977</td></tr>
#
# <tr><td><b> cell data array </b></td><td>chem_0</td></tr>
# </table>
# </table>

# %%
from vedo import dataurl, UnstructuredGrid, Cylinder
ug1 = UnstructuredGrid(dataurl+'ugrid.vtk')
cyl = Cylinder(r=3, height=7).x(3)
ug1.cut_with_mesh(cyl)
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> UnstructuredGrid: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/grids.html#UnstructuredGrid" target="_blank">vedo.grids.UnstructuredGrid</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 13.00<br/>0 ... 2.000<br/>0 ... 3.000</td></tr>
# <tr><td><b> center of mass </b></td><td>(4.44, 1.15, 1.66)</td></tr>
# <tr><td><b> nr. points&nbsp/&nbspcells </b></td><td>33&nbsp/&nbsp18</td></tr>
# <tr><td><b> point data array </b></td><td>SignedDistance</td></tr>
# <tr><td><b> cell data array </b></td><td>elem_val</td></tr>
# </table>
# </table>

# %%
from vedo import StructuredGrid, dataurl
sgrid1 = StructuredGrid(dataurl + "structgrid.vts")
sgrid1
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> StructuredGrid: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/grids.html#StructuredGrid" target="_blank">vedo.grids.StructuredGrid</a></b><br/><code><i>(...usy/.cache/vedo/structgrid.vts)</i></code>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 6.365<br/>-5.144 ... 5.144<br/>23.37 ... 32.89</td></tr>
# <tr><td><b> center of mass </b></td><td>(3.18, 0.111, 28.0)</td></tr>
# <tr><td><b> nr. points&nbsp/&nbspcells </b></td><td>648&nbsp/&nbsp440</td></tr>
# <tr><td><b> point data array </b></td><td>Density</td></tr>
#
# </table>
# </table>

# %%
from vedo import np, RectilinearGrid
xcoords = 7 + np.sqrt(np.arange(0,900,25))
ycoords = np.arange(0, 20)
zcoords = np.arange(0, 20)
rgrid = RectilinearGrid([xcoords, ycoords, zcoords])
rgrid
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> RectilinearGrid: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/grids.html#RectilinearGrid" target="_blank">vedo.grids.RectilinearGrid</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>7.000 ... 36.58<br/>0 ... 19.00<br/>0 ... 19.00</td></tr>
# <tr><td><b> center of mass </b></td><td>(26.6, 9.50, 9.50)</td></tr>
# <tr><td><b> nr. points&nbsp/&nbspcells </b></td><td>14400&nbsp/&nbsp12635</td></tr>
#
#
# </table>
# </table>

# %%
from vedo import Sphere, Axes
axes = Axes(Sphere())
axes
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Axes: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/assembly.html" target="_blank">vedo.assembly.Assembly</a></b>
# <table>
# <tr><td><b> nr. of objects </b></td><td>26</td></tr>
# <tr><td><b> position </b></td><td>(0.0, 0.0, 0.0)</td></tr>
# <tr><td><b> diagonal size </b></td><td>3.7067</td></tr>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>-1.204 ... 1.011<br/>-1.164 ... 1.011<br/>-1.013 ... 1.013</td></tr>
# </table>
# </table>

# %%
from vedo.pyplot import np, histogram
histo = histogram(np.random.randn(1000))
histo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/vedoenv/lib/python3.12/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/vedoenv/lib/python3.12/site-packages/vedo/pyplot.py:267, in Figure._repr_html_(self)
#     254         dots = "..."
#     255     help_text += f"<br/><code><i>({dots}{self.filename[-30:]})</i></code>"
#     257 _all = [
#     258     "<table>",
#     259     "<tr>",
#     260     "<td>",
#     261     image,
#     262     "</td>",
#     263     "<td style='text-align: center; vertical-align: center;'><br/>",
#     264     help_text,
#     265     "<table>",
#     266     "<tr><td><b> nr. of parts </b></td><td>" + str(self.actor.GetNumberOfPaths()) + "</td></tr>",
# --> 267     "<tr><td><b> position </b></td><td>" + str(self.GetPosition()) + "</td></tr>",
#     268     "<tr><td><b> x-limits </b></td><td>" + utils.precision(self.xlim, 4) + "</td></tr>",
#     269     "<tr><td><b> y-limits </b></td><td>" + utils.precision(self.ylim, 4) + "</td></tr>",
#     270     "<tr><td><b> world bounds </b> <br/> (x/y/z) </td><td>" + str(bounds) + "</td></tr>",
#     271     "</table>",
#     272     "</table>",
#     273 ]
#     274 return "\n".join(_all)
#
# AttributeError: 'Histogram1D' object has no attribute 'GetPosition'

# %%
from vedo import LinearTransform
T = LinearTransform()
T.shift([1,2,3]).rotate_z(45).rotate_y(30)
T
# Out:
# vedo.transformations.LinearTransform at (0x7443fd44d3d0)
# name          : LinearTransform
# concatenations: 1
# inverse flag  : False
# matrix 4x4    :
# [[ 0.612372, -0.612372,  0.5     ,  0.887628],
#  [ 0.707107,  0.707107,  0.      ,  2.12132 ],
#  [-0.353553,  0.353553,  0.866025,  2.95163 ],
#  [ 0.      ,  0.      ,  0.      ,  1.      ]]

# %%
from vedo import *

settings.default_backend = 'k3d'  # or k3d, ipyvtk,trame or vtk

sph = Sphere()
sph.cut_with_plane(normal=(1,1,1))
scalars = sph.vertices[:,2] # use z-coords to color vertices

# NB, actions can be concatenated into a pipeline:
# add point scalars with a choice of color map, use flat shading, print infos and then show
sph.cmap('Set3', scalars).add_scalarbar()
sph.show(axes=1, viewup='z')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       9 # NB, actions can be concatenated into a pipeline:
#      10 # add point scalars with a choice of color map, use flat shading, print infos and then show
#      11 sph.cmap('Set3', scalars).add_scalarbar()
# ---> 12 sph.show(axes=1, viewup='z')
#
# File ~/vedoenv/lib/python3.12/site-packages/vedo/visual.py:145, in CommonVisual.show(self, **options)
#     135 def show(self, **options) -> Union["vedo.Plotter", None]:
#     136     """
#     137     Create on the fly an instance of class `Plotter` or use the last existing one to
#     138     show one single object.
#    (...)
#     143     Returns the `Plotter` class instance.
#     144     """
# --> 145     return vedo.plotter.show(self, **options)
#
# File ~/vedoenv/lib/python3.12/site-packages/vedo/plotter.py:361, in show(at, shape, N, pos, size, screensize, title, bg, bg2, axes, interactive, offscreen, sharecam, resetcam, zoom, viewup, azimuth, elevation, roll, camera, mode, screenshot, new, *objects)
#     357                 plt.camera = None
#     359 else:
# --> 361     _plt_to_return = plt.show(
#     362         objects,
#     363         at=at,
#     364         zoom=zoom,
#     365         resetcam=resetcam,
#     366         viewup=viewup,
#     367         azimuth=azimuth,
#     368         elevation=elevation,
#     369         roll=roll,
#     370         camera=camera,
#     371         interactive=interactive,
#     372         mode=mode,
#     373         screenshot=screenshot,
#     374         bg=bg,
#     375         bg2=bg2,
#     376         axes=axes,
#     377     )
#     379 return _plt_to_return
#
# File ~/vedoenv/lib/python3.12/site-packages/vedo/plotter.py:3315, in Plotter.show(self, at, axes, resetcam, zoom, interactive, viewup, azimuth, elevation, roll, camera, mode, rate, bg, bg2, size, title, screenshot, *objects)
#    3313 # Backend ###############################################################
#    3314 if vedo.settings.default_backend in ["k3d", "panel"]:
# -> 3315     return vedo.backends.get_notebook_backend(self.objects)
#    3316 #########################################################################
#    3318 for ia in utils.flatten(objects):
#
# AttributeError: module 'vedo' has no attribute 'backends'

# %%
sph
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Sphere: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/mesh.html" target="_blank">vedo.mesh.Mesh</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>-0.8135 ... 0.9977<br/>-0.8135 ... 0.9977<br/>-0.8146 ... 1.000</td></tr>
# <tr><td><b> center of mass </b></td><td>(0.155, 0.192, 0.361)</td></tr>
# <tr><td><b> average size </b></td><td>0.879</td></tr>
# <tr><td><b> nr. points&nbsp/&nbspfaces </b></td><td>657&nbsp/&nbsp1184</td></tr>
# <tr><td><b> point data array </b></td><td>Scalars</td></tr>
#
# </table>
# </table>
